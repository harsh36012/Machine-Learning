# %% [markdown]
# ## 2. EDA {Univariate Analysis}

# %%
# In this 3 types of analysis are there. {variates are there}
# 1. Univariate - studying with a column.
# 2. Bivariate - studying with 2 columns.
# 3. Multivariate - studying with more then 2 columns.

# %%
# Types of Data
# 1. Numerical Data
# 2. Categorical Data

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 1. Categorical Data

# %% [markdown]
# ### a. value_counts().plot()

# %%
# sns.countplot(df["Survived"].unique())
print(df["Survived"].value_counts())
df["Survived"].value_counts().plot(kind="bar")
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# <Axes: xlabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df["Sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# ### b. PieChart

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df["Pclass"].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## 2. Numerical Data

# %% [markdown]
# ### a. Histogram

# %%
# histogram using sns
sns.histplot(df['Age'],bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

plt.hist(df['Age'],bins=10)
plt.xlabel('Age')
plt.ylabel('No. of People')
# Out:
# Text(0, 0.5, 'No. of People')

# %% [markdown]
# ### b. histplot (pdf)

# %%
# pdf - probability density function.
sns.histplot(df["Age"],kde=True,stat="density")
# eg-> age 40 hone ka kitna percent pro. h? then go to density side, and see around 15% chance h.
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### c. Boxplot

# %%
# sns.boxplot(df['Fare'])
sns.boxplot(df['Fare'],orient='h')
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxplot(df["Age"],orient="h")
# Out:
# <Axes: xlabel='Age'>

# %%
print(df["Age"].min())
# Out:
# 0.42

# %%
print(df["Age"].max())
# Out:
# 80.0

# %%
print(df["Age"].median())
# Out:
# 28.0

# %%
print(df["Age"].mean())
# Out:
# 29.69911764705882

# %%
print(df["Age"].mode())
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# # boxplot ->
# start point -> min
# box start -> 25 percentile
# box middle -> 50 percentile / medain
# box end -> 75 percentile
# last point -> max

# %%
df["Age"].skew()
# if perfectly 0 , then it is perfectly skewed(it is perfectly symetrical)
# if +ve, then positively skew towards right side.
# if -ve , then negatively skew towards legt side.
# Out:
# np.float64(0.38910778230082704)

# %%
df['Age'].plot(kind='density')
# this is towards right(litte bit)
# Out:
# <Axes: ylabel='Density'>
